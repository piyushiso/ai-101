# %% [markdown]
# # PANDAS

# %% [markdown]
# Installing Pandas: pip install pandas
#
# Series: 1D
# DataFrame: 2D

# %%
import pandas as pd
seriesObj = pd.Series([1, 2, 'Apple', 2.44, False])
print(seriesObj)
seriesObj = pd.Series([1, 2, 'Apple', 2.44, False], index=['1', 'Two', 3, 4, 5])
print(seriesObj)
type(seriesObj)
# Out:
# 0        1
# 1        2
# 2    Apple
# 3     2.44
# 4    False
# dtype: object
# 1          1
# Two        2
# 3      Apple
# 4       2.44
# 5      False
# dtype: object
# pandas.core.series.Series

# %%
seriesObj[3]
# scoreSeries['Ram']
# Out:
# 'Apple'

# %%
scores = {
    'Ram': 60,
    'Hari': 40,
    'Shyam': 95
}

scoreSeries = pd.Series(scores)
print(scores, type(scores))
print(scoreSeries)
print(type(scoreSeries))

dict_scores = scoreSeries.to_dict()
print(dict_scores, type(dict_scores))
# Out:
# {'Ram': 60, 'Hari': 40, 'Shyam': 95} <class 'dict'>
# Ram      60
# Hari     40
# Shyam    95
# dtype: int64
# <class 'pandas.core.series.Series'>
# {'Ram': 60, 'Hari': 40, 'Shyam': 95} <class 'dict'>

# %%
scoreSeries.isnull()
# Out:
# Ram      False
# Hari     False
# Shyam    False
# dtype: bool
